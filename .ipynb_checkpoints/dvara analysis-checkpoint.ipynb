# %% [markdown]
# Performing descriptive statistics for the derived variables from the new dataset

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import ConfusionMatrixDisplay

# %%
df1 = pd.read_csv("D:\DDP\preprocessed data\preprocessed_chkpt_0-100000.csv", index_col=0)
df2 = pd.read_csv("D:\DDP\preprocessed data\preprocessed_chkpt_100000-200000.csv", index_col=0)
df3 = pd.read_csv("D:\DDP\preprocessed data\preprocessed_chkpt_200000-300000.csv", index_col=0)
df4 = pd.read_csv("D:\DDP\preprocessed data\preprocessed_chkpt_300000-400000.csv", index_col=0)
df5 = pd.read_csv("D:\DDP\preprocessed data\preprocessed_chkpt_400000-494696.csv", index_col=0)

df = pd.concat([df1, df2, df3, df4, df5])
df = df.drop_duplicates()

# %%
df.columns
# Out:
# Index(['household_id', 'loan_period', 'active_loans_count',
#        'opened_loans_count', 'closed_loans_count', 'churn',
#        'outstanding_loans_end', 'dpd', 'deliquency', 'income_quarter',
#        'expense_quarter', 'instmt_quarter', 'debt_service_ratio',
#        'outstanding_loans_begining', 'churn_prev_five_max',
#        'churn_prev_three_max', 'churn_average_prev_five',
#        'churn_median_prev_five', 'churn_average_prev_eight',
#        'churn_median_prev_eight', 'outstanding_loans_delta',
#        'debt_service_delta', 'cross_bor', 'contributor_number'],
#       dtype='object')

# %%
df['year'] = df['loan_period'].apply(lambda x: x[:4])
q_list = np.sort(df.loan_period.unique()) # just a list from 2010Q1 to 2023Q1

# %% [markdown]
# Let's find out the distribution of the number of quarters for each household

# %%
quarter_counts = df.groupby(['household_id']).loan_period.count()
plt.figure(figsize=(6,4))
plt.hist(quarter_counts, bins = np.arange(1,40))
plt.title('Distribution of number of quarters for each household \n (Bin size=1)')
plt.xlabel('Number of Quarters')
plt.ylabel('Number of households')
plt.show()

quarter_counts.describe()
quarter_counts = quarter_counts.reset_index()
quarter_counts.columns = ['household_id','num_quarters']
df = df.merge(quarter_counts, on='household_id')

# %%
plt.figure(figsize = (6, 4))
temp = df.year.value_counts().sort_index()
plt.bar(temp.index, temp.values)
plt.xlabel('Year')
plt.ylabel('Row frequency')
plt.xticks(rotation = 45)
plt.title('Distribution off years for each row')
plt.show()

# %% [markdown]
# Distribution of features used for time series modelling

# %%
ts_cols = ['active_loans_count',
       'opened_loans_count', 'closed_loans_count', 'churn',
       'outstanding_loans_end','dpd','cross_bor','outstanding_loans_begining','income_quarter',
       'expense_quarter']
df_ts = df[ts_cols]
df_ts.describe()
# Out:
#        active_loans_count  opened_loans_count  closed_loans_count  \
# count        3.871409e+06        3.871409e+06        3.871409e+06
# mean         9.040820e-01        1.390646e-01        5.087037e-03
# std          4.071177e-01        3.524488e-01        7.240504e-02
# min         -3.000000e+00        0.000000e+00        0.000000e+00
# 25%          1.000000e+00        0.000000e+00        0.000000e+00
# 50%          1.000000e+00        0.000000e+00        0.000000e+00
# 75%          1.000000e+00        0.000000e+00        0.000000e+00
# max          1.400000e+01        1.100000e+01        6.000000e+00
#
#               churn  outstanding_loans_end           dpd  cross_bor  \
# count  3.871409e+06           3.871409e+06  3.871409e+06  3871409.0
# mean   2.351599e-03           1.043147e+00  6.437972e+07        1.0
# std    4.883457e-02           2.339482e-01  2.455680e+08        0.0
# min    0.000000e+00           0.000000e+00  0.000000e+00        1.0
# 25%    0.000000e+00           1.000000e+00  0.000000e+00        1.0
# 50%    0.000000e+00           1.000000e+00  0.000000e+00        1.0
# 75%    0.000000e+00           1.000000e+00  1.400000e+01        1.0
# max    4.000000e+00           1.400000e+01  2.000000e+09        1.0
#
#        outstanding_loans_begining  income_quarter  expense_quarter
# count                3.871409e+06    3.871409e+06     3.871409e+06
# mean                 9.091690e-01    1.277175e+06     9.336449e+03
# std                  4.039060e-01    7.975056e+06     1.020783e+04
# min                  0.000000e+00    0.000000e+00     0.000000e+00
# 25%                  1.000000e+00    7.800000e+04     5.125000e+03
# 50%                  1.000000e+00    1.320000e+05     8.400000e+03
# 75%                  1.000000e+00    1.940000e+05     1.220000e+04
# max                  1.400000e+01    1.080000e+09     7.436875e+06

# %% [markdown]
# We select those households which have at least minimum threshold number of quarters for analysis. Also we ignore first few quarters which may have inconsistencies.

# %%
threshold_qtr = 10 # minmum threshold number of quarters. we will consider only households with number of quarters equal to or more than this value for analysis
q_ignore = 2 # first "q_ignore" quarters will be ignored
q_consider = 7 # (q_ignore + 1)'th till (q_ignore + q_consider)'th quarters will be considered


temp = df.groupby('household_id')['loan_period'].count()
subset_hids = temp[temp.values > threshold_qtr].index

# %%
df_subset = pd.DataFrame()

for hid in tqdm(subset_hids):
    temp = df[df.household_id == hid] 
    temp = temp.sort_values(by='loan_period')
    temp = temp.loc[q_ignore : q_ignore+q_consider-1]
    df_subset = pd.concat([df_subset, temp])
# Out:
# 100%|██████████| 78010/78010 [42:30<00:00, 30.59it/s]

# %%
#df_subset.to_csv("D:\DDP\preprocessed data\preprocessed_subset_10_2_7.csv")
df_subset = pd.read_csv("D:\DDP\preprocessed data\preprocessed_subset_10_2_7.csv")

# %% [markdown]
# Calculating the average number of changes in 'q_consider' quarters for each derived variable.

# %%
dpd_last_quarter_list = []
abs_sum_change = dict()

for hid in tqdm(subset_hids):
    temp = df_subset[df_subset.household_id == hid]
    dpd_last_quarter_list.append(temp['dpd'].tolist()[-1])
    for col in ts_cols:
        if col in abs_sum_change:
            abs_sum_change[col]  += (temp[col].diff()[1:]!=0).sum()
        else:
            abs_sum_change[col] = (temp[col].diff()[1:]!=0).sum()
# Out:
#   0%|          | 0/78010 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [7], line 7
#       5 temp = df_subset[df_subset.household_id == hid]
#       6 dpd_last_quarter_list.append(temp['dpd'].tolist()[-1])
# ----> 7 for col in ts_cols:
#       8     if col in abs_sum_change:
#       9         abs_sum_change[col]  += (temp[col].diff()[1:]!=0).sum()
#
# NameError: name 'ts_cols' is not defined

# %% [markdown]
# Distribution of days past due in the last quarter from df_subset

# %%
plt.hist(dpd_last_quarter_list, bins=np.arange(0,300,10))
plt.xlabel('dpd')
plt.ylabel('Number of households')
plt.show()

# %%
# we can see that around 40% of the rows have dpd value as 0
len(dpd_last_quarter_list), (np.array(dpd_last_quarter_list) == 0).sum()
# Out:
# (78010, 31501)

# %%
# general deliquency distribution for the whole dataset is below (ignoring quarters)
# little over 20% has deliquent label
df['deliquency'].sum() , df.shape[0]
# Out:
# (1025463, 3871409)

# %% [markdown]
# Let's find out how many households have been deliquent in at least one quarter

# %%
# 30 lakh out of 38 lakh households have been deliquent in at least one quarter 
# further sanity checks requireds

temp = df.groupby('household_id')['deliquency'].apply(max).reset_index()
temp[temp.deliquency == True].shape
# Out:
# (303997, 2)

# %% [markdown]
# Even better, let's see the distribution of households (number of households) by number of deliquent quarters

# %%
# Distribution of households w.r.t number of deliquent quarters
# Observation: There are exceedingly many households with 0 and 1 deliquent quarters. 
# We need to investaigate why many households have one deliquent quarter

temp = df.groupby('household_id')['deliquency'].apply(sum).reset_index()
plt.figure(figsize = (6, 4))
plt.hist(temp['deliquency'], bins=range(0,15,1))
plt.xlabel('number of deliquent quarters')
plt.ylabel('Number of households')
plt.show()

# %% [markdown]
# From the above plot, the number of households with exactly one deliquent quarter is very high. Let's see the distribution of deliquent quarters for these households.

# %%
temp = df.groupby('household_id')['deliquency'].apply(sum).reset_index()
hid_list_one = temp[temp.deliquency == 1].household_id # list of household_ids for households with exactly one del. quarter
list_1 = df[df.household_id.isin(hid_list_one) & df.deliquency == True].loan_period
data = list_1.value_counts().sort_index()
plt.bar(data.index, data.values)
plt.xlabel('Deliquent Quarter')
plt.ylabel('Number of households')
plt.title('Distribution of housholds with exactly one deliquent quarter')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# We go one step further and see what is the position of the quarter in which the households (with exactly one del. quarter) are deliquent. Note: we are taking about households with exactly one del. quarter.

# %%
qtr_pos_list = []
for hid in tqdm(hid_list_one):
    df_curr = df[df.household_id == hid]
    pos = np.where(df_curr.deliquency == True)[0][0]
    qtr_pos_list.append(pos)
    
plt.figure(figsize=(6, 4))
plt.hist(qtr_pos_list, bins=np.arange(0,40))
plt.xlabel('Position of deliquent quarter \n (w.r.t to the loan range of each household)')
plt.ylabel('Number of households')
plt.show()
# Out:
# 100%|██████████| 160061/160061 [17:14<00:00, 154.77it/s]

# %%
# proportion of rows with dpd 1e9 (i.e XXX originally)

(df[df.dpd == 1e9].shape[0] / df.shape[0]) * 100

# 6.5% of the rows have 1e9 as dpd
# Out:
# 6.419988174847968

# %% [markdown]
# DPD values turned out to be 1e9 for most of these housholds with one deliquent quarter. 1e9 was the value I used to replace "XXX" in my preprocessing step. Let's plot the same plot again, this time after dropping those rows with 1e9.

# %%
temp = df[df.dpd!=1e9].groupby('household_id')['deliquency'].apply(sum).reset_index()
hid_list_one_drop_xxx = temp[temp.deliquency == 1].household_id # list of household_ids for households with exactly one del. quarter
list_1_drop_xxx = df[df.household_id.isin(hid_list_one_drop_xxx) & df.deliquency == True].loan_period
data_drop_xxx = list_1_drop_xxx.value_counts().sort_index()
plt.bar(data_drop_xxx.index, data_drop_xxx.values)
plt.xlabel('Deliquent Quarter')
plt.ylabel('Number of households')
plt.title('Distribution of housholds with exactly one deliquent quarter \n (rows with 1e9 as dpd dropped)')
plt.xticks(rotation=90)
plt.show()

# %%
# after dropping rows with dpd = 1e9

qtr_pos_list_drop_xxx = []
for hid in tqdm(hid_list_one_drop_xxx):
    df_curr = df[df.household_id == hid]
    pos = np.where(df_curr.deliquency == True)[0][0]
    qtr_pos_list_drop_xxx.append(pos)
    
plt.figure(figsize=(6, 4))
plt.hist(qtr_pos_list_drop_xxx, bins=np.arange(0,40))
plt.xlabel('Position of deliquent quarter \n (w.r.t to the loan range of each household)')
plt.ylabel('Number of households')
plt.show()
# Out:
# 100%|██████████| 33406/33406 [03:31<00:00, 157.91it/s]

# %% [markdown]
# Are there some years where deliquency was more or less compared to others due to the impact of COVID-19? Let's plot the distribution of deliquent households by quarter. We also plot the distribution in terms of fraction of deliquent households by quarter.

# %%
df_deliquent = df[df.deliquency == True]
df_del_qtr = df_deliquent.groupby('loan_period')['household_id'].apply(lambda x: len(np.unique(x))).sort_index().reset_index()
df_del_qtr.columns = ['loan_period', 'deliquent_households']
df_qtr = df.groupby('loan_period')['household_id'].apply(lambda x: len(np.unique(x))).sort_index().reset_index()
df_qtr.columns = ['loan_period', 'households']

plt.figure(figsize=(8,4))
plt.bar(df_del_qtr.loan_period, df_del_qtr.deliquent_households)
plt.xlabel('year')
plt.ylabel('Number of deliquent households')
plt.xticks(rotation=90)
plt.show()

df_count = df_qtr.merge(df_del_qtr, on='loan_period', how='left')
df_count = df_count.fillna(0)
df_count['deliquent_households_frac'] = df_count.deliquent_households / df_count.households


plt.figure(figsize=(12,4))
plt.bar(df_count.loan_period, df_count.deliquent_households_frac)
plt.xlabel('year')
plt.ylabel('Fraction of deliquent households')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# One reasonable baseline model in deliquency prediction for the q'th quarter is outputting the deliquency of (q-1)th quarter. Here q can be considered as a parameter of our choice. For example, if a household is deliquent in the 9th quarter, we predict the deliquency for the 10th quarter to be true.
#
# Let's make confusion matrices for different q values.
# Note: For each q value, we will obviously consider households which households which have at least q quarters

# %%
q = 7
y_q_minus_1 = []
y_q = []

df_thresh = df[df.num_quarters >= q]
hid_list = df_thresh.household_id.unique()

for hid in tqdm(hid_list):
    temp = df_thresh.loc[(df_thresh.household_id == hid),'deliquency']
    y_q_mins_1.append(temp.iloc[q-2])
    y_q.append(temp.iloc[q-1])
# Out:
# 100%|██████████| 258283/258283 [27:18<00:00, 157.60it/s]

# %%
plt.figure(figsize=(6, 4))
cm = confusion_matrix(y_q_minus_1, y_q,  normalize='true', labels=[False, True])
cm_display = ConfusionMatrixDisplay(confusion_matrix = cm)
cm_display.plot()
plt.xlabel('qth quarter')
plt.ylabel("(q-1)'th quarter")
plt.title('Deliquency for q={}'.format(q))
plt.show()

# %% [markdown]
# Let's evaluate the performance of this baseline model on the subset dataset for qth quarter

# %%
# the baseline classification report looks too good to be true

y_pred = y_q_mins_1
y_true = y_q
print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.93      0.94      0.94    185562
#         True       0.85      0.83      0.84     72721
#
#     accuracy                           0.91    258283
#    macro avg       0.89      0.89      0.89    258283
# weighted avg       0.91      0.91      0.91    258283

# %% [markdown]
# Out of the all the rows labelled "deliquent", how many of them are actually due to have missing dpd and thus being replaced with 1e9? Let's look at this.

# %%
print("missing dpd :",df[df.dpd == 1e9].shape[0])
print("labelled as deliquent :", df[df.deliquency == True].shape[0])
# Out:
# missing dpd : 248544
# labelled as deliquent : 1025463
